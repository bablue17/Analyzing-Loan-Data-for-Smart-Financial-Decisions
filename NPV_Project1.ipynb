# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##### 1.Import the dataset and understand it

# %%
df=pd.read_csv('loan.csv')

# %%
df.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#   int_rate  installment grade emp_length  ...         purpose    dti  \
# 0   10.65%       162.87     B  10+ years  ...     credit_card  27.65
# 1   15.27%        59.83     C   < 1 year  ...             car   1.00
# 2   15.96%        84.33     C  10+ years  ...  small_business   8.72
# 3   13.49%       339.31     C  10+ years  ...           other  20.00
# 4   12.69%        67.79     B     1 year  ...           other  17.94
#
#     total_pymnt total_pymnt_inv  total_rec_prncp  total_rec_int  last_pymnt_d  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   39717 non-null  int64
#  1   member_id            39717 non-null  int64
#  2   loan_amnt            39717 non-null  int64
#  3   funded_amnt          39717 non-null  int64
#  4   funded_amnt_inv      39717 non-null  float64
#  5   term                 39717 non-null  object
#  6   int_rate             39717 non-null  object
#  7   installment          39717 non-null  float64
#  8   grade                39717 non-null  object
#  9   emp_length           38642 non-null  object
#  10  annual_inc           39717 non-null  float64
#  11  verification_status  39717 non-null  object
#  12  loan_status          39717 non-null  object
#  13  purpose              39717 non-null  object
#  14  dti                  39717 non-null  float64
# ...

# %%
df.describe()
# Out:
#                  id     member_id     loan_amnt   funded_amnt  \
# count  3.971700e+04  3.971700e+04  39717.000000  39717.000000
# mean   6.831319e+05  8.504636e+05  11219.443815  10947.713196
# std    2.106941e+05  2.656783e+05   7456.670694   7187.238670
# min    5.473400e+04  7.069900e+04    500.000000    500.000000
# 25%    5.162210e+05  6.667800e+05   5500.000000   5400.000000
# 50%    6.656650e+05  8.508120e+05  10000.000000   9600.000000
# 75%    8.377550e+05  1.047339e+06  15000.000000  15000.000000
# max    1.077501e+06  1.314167e+06  35000.000000  35000.000000
#
#        funded_amnt_inv   installment    annual_inc           dti  \
# count     39717.000000  39717.000000  3.971700e+04  39717.000000
# mean      10397.448868    324.561922  6.896893e+04     13.315130
# std        7128.450439    208.874874  6.379377e+04      6.678594
# min           0.000000     15.690000  4.000000e+03      0.000000
# 25%        5000.000000    167.020000  4.040400e+04      8.170000
# ...

# %% [markdown]
# ##### 2.List down the number of rows and columns

# %%
df.shape
# Out:
# (39717, 23)

# %% [markdown]
# There are 39717 rows and 23 columns

# %% [markdown]
# ##### 3.Int_rate’ column is character type. With the help of lambda function convert into float type.

# %%
df['int_rate']=list(map(lambda x:float(x.strip('%')),df['int_rate']))

# %% [markdown]
# ##### 4.Check the datatype of each colum

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   39717 non-null  int64
#  1   member_id            39717 non-null  int64
#  2   loan_amnt            39717 non-null  int64
#  3   funded_amnt          39717 non-null  int64
#  4   funded_amnt_inv      39717 non-null  float64
#  5   term                 39717 non-null  object
#  6   int_rate             39717 non-null  float64
#  7   installment          39717 non-null  float64
#  8   grade                39717 non-null  object
#  9   emp_length           38642 non-null  object
#  10  annual_inc           39717 non-null  float64
#  11  verification_status  39717 non-null  object
#  12  loan_status          39717 non-null  object
#  13  purpose              39717 non-null  object
#  14  dti                  39717 non-null  float64
# ...

# %% [markdown]
# ##### 5.Cleaning the dataset- Remove the columns having complete NaN value in the entire dataset

# %%
df.isnull().sum()
# Out:
# id                         0
# member_id                  0
# loan_amnt                  0
# funded_amnt                0
# funded_amnt_inv            0
# term                       0
# int_rate                   0
# installment                0
# grade                      0
# emp_length              1075
# annual_inc                 0
# verification_status        0
# loan_status                0
# purpose                    0
# dti                        0
# total_pymnt                0
# total_pymnt_inv            0
# total_rec_prncp            0
# total_rec_int              0
# last_pymnt_d              71
# last_pymnt_amnt            0
# Unnamed: 21            39717
# Unnamed: 22            39717
# dtype: int64

# %% [markdown]
# Unnamed: 21 and Unnamed: 22  have complete NaN values, therefore removing it

# %%
df.drop(df[['Unnamed: 21','Unnamed: 22']],axis=1,inplace=True)

# %%
df
# Out:
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0      1077501    1296599       5000         5000           4975.0
# 1      1077430    1314167       2500         2500           2500.0
# 2      1077175    1313524       2400         2400           2400.0
# 3      1076863    1277178      10000        10000          10000.0
# 4      1075358    1311748       3000         3000           3000.0
# ...        ...        ...        ...          ...              ...
# 39712    92187      92174       2500         2500           1075.0
# 39713    90665      90607       8500         8500            875.0
# 39714    90395      90390       5000         5000           1325.0
# 39715    90376      89243       5000         5000            650.0
# 39716    87023      86999       7500         7500            800.0
#
#              term  int_rate  installment grade emp_length  ...  \
# 0       36 months     10.65       162.87     B  10+ years  ...
# ...

# %% [markdown]
# ##### 6.Write the code to find the value counts of the ‘loan_status’ category column and filter only the ‘fully paid’ and ‘charged off’ categories.

# %%
df['loan_status'].value_counts().iloc[0:2]
# Out:
# Fully Paid     32950
# Charged Off     5627
# Name: loan_status, dtype: int64

# %%
df[(df['loan_status']=='Fully Paid')|(df['loan_status']=='Charged Off')]
# Out:
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0      1077501    1296599       5000         5000           4975.0
# 1      1077430    1314167       2500         2500           2500.0
# 2      1077175    1313524       2400         2400           2400.0
# 3      1076863    1277178      10000        10000          10000.0
# 5      1075269    1311441       5000         5000           5000.0
# ...        ...        ...        ...          ...              ...
# 39712    92187      92174       2500         2500           1075.0
# 39713    90665      90607       8500         8500            875.0
# 39714    90395      90390       5000         5000           1325.0
# 39715    90376      89243       5000         5000            650.0
# 39716    87023      86999       7500         7500            800.0
#
#              term  int_rate  installment grade emp_length  ...  \
# 0       36 months     10.65       162.87     B  10+ years  ...
# ...

# %%
#Another way

# %%
df[df['loan_status'].isin(['Fully Paid','Charged Off'])]
# Out:
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0      1077501    1296599       5000         5000           4975.0
# 1      1077430    1314167       2500         2500           2500.0
# 2      1077175    1313524       2400         2400           2400.0
# 3      1076863    1277178      10000        10000          10000.0
# 5      1075269    1311441       5000         5000           5000.0
# ...        ...        ...        ...          ...              ...
# 39712    92187      92174       2500         2500           1075.0
# 39713    90665      90607       8500         8500            875.0
# 39714    90395      90390       5000         5000           1325.0
# 39715    90376      89243       5000         5000            650.0
# 39716    87023      86999       7500         7500            800.0
#
#              term  int_rate  installment grade emp_length  ...  \
# 0       36 months     10.65       162.87     B  10+ years  ...
# ...

# %% [markdown]
# ##### 7.Filter the ‘Emp_Len’ column to extract the numerical value from the string. Hint - Emp_len : < 1year, 2 years , 3 years as 1 , 2, 3 so on.

# %%
df['emp_length']=df['emp_length'].str.extract('(\d+)').astype(float)

# %%
df.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#    int_rate  installment grade  emp_length  ...  verification_status  \
# 0     10.65       162.87     B        10.0  ...             Verified
# 1     15.27        59.83     C         1.0  ...      Source Verified
# 2     15.96        84.33     C        10.0  ...         Not Verified
# 3     13.49       339.31     C        10.0  ...      Source Verified
# 4     12.69        67.79     B         1.0  ...      Source Verified
#
#    loan_status         purpose    dti   total_pymnt  total_pymnt_inv  \
# ...

# %% [markdown]
# ##### 8.Using the Lambda function, remove the month from the ‘term’ columnsuch that ‘36 months’, ‘60 months’ appear as 36 and 60 respectively.

# %%
df['term']=df['term'].map(lambda x:x[1:3])

# %%
df.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv term  int_rate  \
# 0  1077501    1296599       5000         5000           4975.0   36     10.65
# 1  1077430    1314167       2500         2500           2500.0   60     15.27
# 2  1077175    1313524       2400         2400           2400.0   36     15.96
# 3  1076863    1277178      10000        10000          10000.0   36     13.49
# 4  1075358    1311748       3000         3000           3000.0   60     12.69
#
#    installment grade  emp_length  ...  verification_status  loan_status  \
# 0       162.87     B        10.0  ...             Verified   Fully Paid
# 1        59.83     C         1.0  ...      Source Verified  Charged Off
# 2        84.33     C        10.0  ...         Not Verified   Fully Paid
# 3       339.31     C        10.0  ...      Source Verified   Fully Paid
# 4        67.79     B         1.0  ...      Source Verified      Current
#
# ...

# %% [markdown]
# ##### 9.Create a new column as risky_loan_applicant by comparing loan_amnt and funded_amnt with the following criteria -
# ##### If loan_amnt is less than equals to funded_amnt set it as ‘0’ else set it as ‘1’.

# %%
df.insert(4,'risky_loan_applicant',
          df[['loan_amnt','funded_amnt']].apply(lambda x: 0 if x['loan_amnt'] <= x['funded_amnt'] else 1 ,axis=1))

# %%
df.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  risky_loan_applicant  \
# 0  1077501    1296599       5000         5000                     0
# 1  1077430    1314167       2500         2500                     0
# 2  1077175    1313524       2400         2400                     0
# 3  1076863    1277178      10000        10000                     0
# 4  1075358    1311748       3000         3000                     0
#
#    funded_amnt_inv term  int_rate  installment grade  ...  \
# 0           4975.0   36     10.65       162.87     B  ...
# 1           2500.0   60     15.27        59.83     C  ...
# 2           2400.0   36     15.96        84.33     C  ...
# 3          10000.0   36     13.49       339.31     C  ...
# 4           3000.0   60     12.69        67.79     B  ...
#
#    verification_status  loan_status         purpose    dti   total_pymnt  \
# 0             Verified   Fully Paid     credit_card  27.65   5863.155187
# ...

# %% [markdown]
# ##### 10.Using the bar plot visualize the loan_status column against categorical column grade, term, verification_status . Write the observation from each graph.

# %%
#Loan Status Vs Grade
pd.crosstab(df['loan_status'],df['grade']).plot(kind='bar')
plt.show()

# %%
#Inference:
#1. Most number of people have fully paid the loan
#2. Amongst all the Grades, "B" Graded people are the majority who have totally paid, have current and charged off their loans
#3. There are only few members in current column who paid their loan on time

# %%
#Loan Status Vs Term
pd.crosstab(df['loan_status'],df['term']).plot(kind='bar')
plt.show()

# %%
#Inference:
#1. Those who have 36 months of term period to pay the loan either tottaly paid their loans or they have charged off,
#but the majority are the ones who have totally paid their loans
#2.Those who have 60 months of term period are also paid their loans or currently paying their loans.
#Peope who charged off their loans are lesser as compared to 36 months

# %%
#Loan Status Vs Verification Status

# %%
pd.crosstab(df['loan_status'],df['verification_status']).plot(kind='bar')
plt.show()

# %%
#Inference:
#1. From the above inference those who totally paid their loans are mostly not verified
#2. In both fully paid and charged off loan status there are more number of people who hasnt verified yet.

# %% [markdown]
# ##### 11.Using a user defined function convert the ‘emp_len’ column into
# ##### categorical column as follows -
# ##### If emp_len is less than equals to 1 then recode as ‘fresher’.
# ##### If emp_len is greater than 1 and less than 3 then recode as ‘junior’.
# ##### If emp_len is greater than 3 and less than 7 then recode as ‘senior’
# ##### If emp_len is greater than 7 then recode as ‘expert

# %%
def emp_level(x):
    if x <=1:
        return 'Fresher'
    elif x>1 and x<=3:
        return 'Junior'
    elif x>3 and x<=7:
        return 'Senior'
    else:
        return 'Expert'

# %%
df['emp_length']=df['emp_length'].apply(emp_level)

# %%
df.loc[:,['emp_length']]
# Out:
#       emp_length
# 0         Expert
# 1        Fresher
# 2         Expert
# 3         Expert
# 4        Fresher
# ...          ...
# 39712     Senior
# 39713     Junior
# 39714    Fresher
# 39715    Fresher
# 39716    Fresher
#
# [39717 rows x 1 columns]

# %% [markdown]
# ##### 12.Find the sum of ‘loan_amnt’ for each grade and display the distribution of ‘loan_amnt’ using a pie plot

# %%
df.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  risky_loan_applicant  \
# 0  1077501    1296599       5000         5000                     0
# 1  1077430    1314167       2500         2500                     0
# 2  1077175    1313524       2400         2400                     0
# 3  1076863    1277178      10000        10000                     0
# 4  1075358    1311748       3000         3000                     0
#
#    funded_amnt_inv term  int_rate  installment grade  ... verification_status  \
# 0           4975.0   36     10.65       162.87     B  ...            Verified
# 1           2500.0   60     15.27        59.83     C  ...     Source Verified
# 2           2400.0   36     15.96        84.33     C  ...        Not Verified
# 3          10000.0   36     13.49       339.31     C  ...     Source Verified
# 4           3000.0   60     12.69        67.79     B  ...     Source Verified
#
#    loan_status         purpose    dti   total_pymnt  total_pymnt_inv  \
# ...

# %%
#Sum of Loan Amount
loan_grade_sum=df.groupby('grade')['loan_amnt'].sum()
loan_grade_sum
# Out:
# grade
# A     86982400
# B    133651350
# C     89115825
# D     65160400
# E     45037900
# F     19263100
# G      6391675
# Name: loan_amnt, dtype: int64

# %%
plt.pie(loan_grade_sum.values,labels=loan_grade_sum.index,autopct='%.2f%%')
plt.show()
